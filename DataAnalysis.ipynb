# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LogNorm
import matplotlib as mpl
from mpl_toolkits.axes_grid1 import ImageGrid
from mpl_toolkits import mplot3d
import matplotlib.font_manager as font_manager

labelsTNR = {'fontname':'Times New Roman'}
mpl.rcParams['mathtext.fontset'] = 'custom'
mpl.rcParams['mathtext.bf'] = 'STIXGeneral:italic:bold'
TNR = font_manager.FontProperties(family='Times New Roman',
                                   style='italic', size=16)
df = pd.read_csv('Dataset.csv')
df
# Out:
#            OBJECT  SPEED  ACC  SAMPLE  TIME [s]  FORCE [N]
# 0        Object_1    100  100       1     0.000    -0.9328
# 1        Object_1    100  100       1     0.001    -0.9548
# 2        Object_1    100  100       1     0.002    -0.8284
# 3        Object_1    100  100       1     0.003    -0.8356
# 4        Object_1    100  100       1     0.004    -0.8408
# ...           ...    ...  ...     ...       ...        ...
# 3009207  Object_4    300  300      16     3.845    -0.7940
# 3009208  Object_4    300  300      16     3.846    -0.7580
# 3009209  Object_4    300  300      16     3.847    -0.8264
# 3009210  Object_4    300  300      16     3.848    -0.8304
# 3009211  Object_4    300  300      16     3.849    -0.7332
#
# [3009212 rows x 6 columns]

# %%
t_sample = 'Sample'
t_time = 'Time'
t_force = 'Force'
t_speed = 'Speed'
t_acceleration = 'Acceleration'
t_object = 'Object'
t_jawForce = 'Jaw squeeze force'

# %%
#Matryca_6kat_1 Matryca_okgragla
new13 = df.loc[(df['OBJECT'] == "Object_3") 
               & (df['SPEED'] == 100) 
               & (df['ACC'] == 100)
              & (df['SAMPLE'] == 1)]
new14 = df.loc[(df['OBJECT'] == "Object_3") 
               & (df['SPEED'] == 100) 
               & (df['ACC'] == 100)
              & (df['SAMPLE'] == 2)]
new15 = df.loc[(df['OBJECT'] == "Object_3") 
               & (df['SPEED'] == 100) 
               & (df['ACC'] == 100)
              & (df['SAMPLE'] == 3)]
new16 = df.loc[(df['OBJECT'] == "Object_3") 
               & (df['SPEED'] == 100) 
               & (df['ACC'] == 100)
              & (df['SAMPLE'] == 6)]
# new17 = df.loc[(df['OBJECT'] == "Matryca_okgragla") 
#                & (df['SPEED'] == "plaskieTPU") 
#                & (df['Sila'] == 0)
#               & (df['Pomiar'] == 0)]
# new18 = df.loc[(df['OBJECT'] == "Matryca_okgragla") 
#                & (df['SPEED'] == "plaskieTPU") 
#                & (df['Sila'] == 0)
#               & (df['Pomiar'] == 0)]

fig = plt.figure(figsize=(6,6))
ax = plt.axes()
x1 = new13['TIME [s]'].values
y1 = new13['FORCE [N]'].values
x2 = new14['TIME [s]'].values
y2 = new14['FORCE [N]'].values
x3 = new15['TIME [s]'].values
y3 = new15['FORCE [N]'].values
x4 = new16['TIME [s]'].values
y4 = new16['FORCE [N]'].values
# x5 = new17['TIME [s]'].values
# y5 = new17['FORCE [N]'].values
# x6 = new18['TIME [s]'].values
# y6 = new18['FORCE [N]'].values

ax.set_xlabel('{}'.format(t_time)+' $\mathbf{t}$[s]',**labelsTNR, size=16)
ax.set_ylabel('{}'.format(t_force)+ ' $\mathbf{F}$[N]',**labelsTNR, size=16)
ax.set_title('{}: 100, {}: 100'.format(t_speed,t_acceleration),**labelsTNR, size=16)
# plt.xticks([0,11,1])
#plt.xticks(np.arange(0, 34, 2),**labelsTNR, size=16)
#plt.yticks(np.arange(0, 40.0005, 4),**labelsTNR, size=16)
plt.grid(color='0.2', linestyle='-', linewidth=0.5)

# ax.plot(x1, y1, 'mediumblue', label='$\mathbf{Obiekt 1}$', linewidth=0.5)
# ax.plot(x2, y2, 'red', label='$\mathbf{Obiekt 2}$', linewidth=0.5)
# ax.plot(x3, y3, 'orange', label='$\mathbf{Obiekt 3}$', linewidth=0.5)
# ax.plot(x4, y4, 'limegreen', label='$\mathbf{Obiekt 4}$', linewidth=0.5)
ax.plot(x1, y1, 'mediumblue', label='{} 1'.format(t_sample), linewidth=1)
ax.plot(x2, y2, 'red', label='{} 2'.format(t_sample), linewidth=1)
ax.plot(x3, y3, 'orange', label='{} 3'.format(t_sample), linewidth=1)
ax.plot(x4, y4, 'limegreen', label='{} 4'.format(t_sample), linewidth=1)
#ax.plot(x5, y5, 'black', label='5')
#ax.plot(x6, y6, 'pink', label='6')

plt.legend(loc='lower center',fontsize=12,prop=TNR)

#ax.set_xlim(0,22)
#ax.set_ylim(0,40.05)
#plt.savefig('wykresBuffor.png', format='png',dpi=200, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10,6))
ax = plt.axes()
objecT = "Object_1"
speed = 100
acc = 100

for i in range(1,17):
    new = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)]
    x = new['TIME [s]'].values
    y = new['FORCE [N]'].values+0.8
    ax.plot(x, y, label='Pomiar {}'.format(i), linewidth=1)
    
ax.set_xlabel('{}'.format(t_time)+' $\mathbf{t}$[s]',**labelsTNR, size=16)
ax.set_ylabel('{}'.format(t_force)+ ' $\mathbf{F}$[N]',**labelsTNR, size=16)
ax.set_title('{} {}, {}: {} mm/s, {}: {} mm/s\u00b2'.format(t_object,objecT[7],t_speed,speed,t_acceleration,acc),**labelsTNR, size=16)
# plt.xticks([0,11,1])
#plt.xticks(np.arange(0, 34, 2),**labelsTNR, size=16)
#plt.yticks(np.arange(0, 40.0005, 4),**labelsTNR, size=16)
plt.grid(color='0.2', linestyle='-', linewidth=0.5)
plt.legend(loc='lower center',bbox_to_anchor=(0.9,0.,0.5, 0.5),prop=TNR)

#ax.set_xlim(0,22)
#ax.set_ylim(0,40.05)
#plt.savefig('wykresBuffor.png', format='png',dpi=200, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(16,6))
ax = plt.axes()
objecT = "Object_2"
speed = 100
acc = 100
tablee = [1,3,4,5,7,8,10,12]
k=0

for i in range(3,4,1):
# for i in tablee:
    new = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)]
    x = new['TIME [s]'].values
    y = new['FORCE [N]'].values+0.8
    k = k+1
    ax.plot(x, y, label='{} {}'.format(t_sample,k), linewidth=2)
    
ax.set_xlabel('{}'.format(t_time)+' $\mathbf{t}$ [s]',**labelsTNR, size=16)
ax.set_ylabel('{}'.format(t_jawForce)+' $\mathbf{F}$ [N]',**labelsTNR, size=16)

# plt.xticks([0,11,1])
#plt.xticks(np.arange(0, 34, 2),**labelsTNR, size=16)
#plt.yticks(np.arange(0, 40.0005, 4),**labelsTNR, size=16)
plt.grid(color='0.2', linestyle='-', linewidth=0.5)
#plt.legend(loc='lower center',fontsize=12,ncols=2,bbox_to_anchor=(0.10,0,0.5,0.5))

plt.axvline(x = 0.415, color = 'r', label = 'axvline - full height')
plt.axvline(x = 1.16, color = 'y', label = 'axvline - full height')
plt.axvline(x = 5.5, color = 'g', label = 'axvline - full height')
plt.axvline(x = 6.150, color = 'cyan', label = 'axvline - full height')


ax.set_xlim(0,7)
ax.set_ylim(0,35.0005)
#plt.savefig('wykresBuffor.png', format='png',dpi=300, bbox_inches='tight')
# Out:
# (0.0, 35.0005)

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.axes()
objecT = "Object_2"
speed = 100
acc = 100
tablee = [1,3,4,5,7,8,10,12]
k=0

for i in range(1,17,2):
# for i in tablee:
    new = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)]
    x = new['TIME [s]'].values
    y = new['FORCE [N]'].values+0.8
    k = k+1
    ax.plot(x, y, label='{} {}'.format(t_sample,k), linewidth=2)
    
ax.set_xlabel('{}'.format(t_time)+' $\mathbf{t}$ [s]',**labelsTNR, size=16)
ax.set_ylabel('{}'.format(t_jawForce)+' $\mathbf{F}$ [N]',**labelsTNR, size=16)
ax.set_title('{} {}, {}: {} mm/s, {}: {} mm/s\u00b2'.format(t_object,objecT[7],t_speed,speed,t_acceleration,acc),**labelsTNR, size=16)
# plt.xticks([0,11,1])
#plt.xticks(np.arange(0, 34, 2),**labelsTNR, size=16)
#plt.yticks(np.arange(0, 40.0005, 4),**labelsTNR, size=16)
plt.grid(color='0.2', linestyle='-', linewidth=0.5)
#plt.legend(loc='lower center',fontsize=12,ncols=2,bbox_to_anchor=(0.10,0.1,0.5,0.5))

plt.axvline(x = 2, color = 'r', label = 'axvline - full height')
plt.axvline(x = 3, color = 'y', label = 'axvline - full height')

ax.set_xlim(0,7)
ax.set_ylim(0,35.0005)
#plt.savefig('wykresBuffor.png', format='png',dpi=300, bbox_inches='tight')
# Out:
# (0.0, 35.0005)

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.axes()
objecT = "Object_2"
speed = 100
acc = 100
tablee = [1,3,4,5,7,8,10,12]
k=0

for i in range(1,17,2):
# for i in tablee:
    new = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)]
    x = new['TIME [s]'].values
    y = new['FORCE [N]'].values+0.8
    k = k+1
    ax.plot(x, y, label='{} {}'.format(t_sample,k), linewidth=2)
    
# plt.xticks([0,11,1])
plt.xticks(np.arange(2, 3.0005, 0.2),**labelsTNR, size=16)
plt.yticks(np.arange(20, 25.0005, 1),**labelsTNR, size=16)
plt.grid(color='0.2', linestyle='-', linewidth=0.5)

plt.axhline(y = 24.65, color = 'r')
plt.axhline(y = 20.95, color = 'gold')

ax.set_xlim(2,3)
ax.set_ylim(20,25.0005)
#plt.savefig('wykresBuffor.png', format='png',dpi=300, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.axes()
objecT = "Object_2"
speed = 300
acc = 300
tablee = [1,3,4,5,7,8,10,12]
k=0

#for i in range(1,17,2):
for i in tablee:
    new = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)]
    x = new['TIME [s]'].values
    y = new['FORCE [N]'].values+0.8
    k = k+1
    ax.plot(x, y, label='{} {}'.format(t_sample,k), linewidth=0.5)
    
ax.set_xlabel('{}'.format(t_time)+' $\mathbf{t}$ [s]',**labelsTNR, size=16)
ax.set_ylabel('{}'.format(t_jawForce)+' $\mathbf{F}$ [N]',**labelsTNR, size=16)
ax.set_title('{} {}, {}: {} mm/s, {}: {} mm/s\u00b2'.format(t_object,objecT[7],t_speed,speed,t_acceleration,acc),**labelsTNR, size=16)
# plt.xticks([0,11,1])
#plt.xticks(np.arange(0, 34, 2),**labelsTNR, size=16)
#plt.yticks(np.arange(0, 40.0005, 4),**labelsTNR, size=16)
plt.grid(color='0.2', linestyle='-', linewidth=0.5)
plt.legend(loc='lower center',ncols=1,bbox_to_anchor=(1,0.1,0.5,0.5),prop=TNR)

plt.axvline(x = 2, color = 'r', label = 'axvline - full height')
plt.axvline(x = 3, color = 'y', label = 'axvline - full height')

ax.set_xlim(0,7)
ax.set_ylim(0,35.0005)
#plt.savefig('wykresBuffor.png', format='png',dpi=300, bbox_inches='tight')
# Out:
# (0.0, 35.0005)

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.axes()
objecT = "Object_2"
speed = 300
acc = 300
tablee = [1,3,4,5,7,8,10,12]
k=0

#for i in range(1,17,2):
for i in tablee:
    new = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)]
    x = new['TIME [s]'].values
    y = new['FORCE [N]'].values+0.8
    k = k+1
    ax.plot(x, y, label='{} {}'.format(t_sample,k), linewidth=0.5)
    
# plt.xticks([0,11,1])
plt.xticks(np.arange(2, 4, 0.2),**labelsTNR, size=16)
plt.yticks(np.arange(22, 28.0005, 1),**labelsTNR, size=16)
plt.grid(color='0.2', linestyle='-', linewidth=0.5)

plt.axhline(y = 27.55, color = 'r')
plt.axhline(y = 22.95, color = 'gold')

ax.set_xlim(2,3)
ax.set_ylim(22,28.0005)
#plt.savefig('wykresBuffor.png', format='png',dpi=300, bbox_inches='tight')
# Out:
# (22.0, 28.0005)

# %%
fig = plt.figure(figsize=(8,6))
ax = plt.axes()
objecT = "Object_2"
speed = 300
acc = 300
tablee = [1,3,4,5,7,8,10,12]
k=0

for i in range(1,17,1):
    new = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)]
    x = new['TIME [s]'].values
    y = new['FORCE [N]'].values+0.8
    k = k+1
    ax.plot(x, y, label='{} {}'.format(t_sample,k), linewidth=0.5)
    
ax.set_xlabel('{}'.format(t_time)+' $\mathbf{t}$ [s]',**labelsTNR, size=16)
ax.set_ylabel('{}'.format(t_jawForce)+' $\mathbf{F}$ [N]',**labelsTNR, size=16)
ax.set_title('{} {}, {}: {} mm/s, {}: {} mm/s\u00b2'.format(t_object,objecT[7],t_speed,speed,t_acceleration,acc),**labelsTNR, size=16)
# plt.xticks([0,11,1])
#plt.xticks(np.arange(0, 34, 2),**labelsTNR, size=16)
#plt.yticks(np.arange(0, 40.0005, 4),**labelsTNR, size=16)
plt.grid(color='0.2', linestyle='-', linewidth=0.5)
plt.legend(loc='lower center',ncols=1,bbox_to_anchor=(1,0.1,0.5,0.5),prop=TNR)

plt.axvline(x = 2, color = 'r', label = 'axvline - full height')
plt.axvline(x = 3, color = 'y', label = 'axvline - full height')

ax.set_xlim(0,7)
ax.set_ylim(0,35.0005)
#plt.savefig('wykresBuffor.png', format='png',dpi=300, bbox_inches='tight')
# Out:
# (0.0, 35.0005)

# %%
fig = plt.figure(figsize=(3,10))
ax = plt.axes()
objecT = "Object_1"
speed = 100
acc = 100
tablee = [1,3,4,5,7,8,10,12]
k=0

for i in range(0,17,1):
    new = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)]
    x = new['TIME [s]'].values
    y = new['FORCE [N]'].values+0.8
    k = k+1
    ax.plot(x, y, label='{} {}'.format(t_sample,k), linewidth=0.5)
    
# plt.xticks([0,11,1])
plt.xticks(np.arange(2, 4, 0.2),**labelsTNR, size=16)
plt.yticks(np.arange(23, 28.5005, 1),**labelsTNR, size=16)
plt.grid(color='0.2', linestyle='-', linewidth=0.5)

plt.axhline(y = 32.55, color = 'r')
plt.axhline(y = 22.95, color = 'gold')

ax.set_xlim(2,3)
ax.set_ylim(23,28.5005)
#plt.savefig('wykresBuffor.png', format='png',dpi=300, bbox_inches='tight')
# Out:
# (23.0, 28.5005)

# %%
x1 = []
x2 = []
d = []
a = []
objecT = "Object_2"
speed = 100
acc = 100
for i in range(1,17):
    new1 = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)
                & (df['TIME [s]'] == 2)]
    new2 = df.loc[(df['OBJECT'] == objecT) 
               & (df['SPEED'] == speed) 
               & (df['ACC'] == acc)
              & (df['SAMPLE'] == i)
                & (df['TIME [s]'] == 3)]
    # print(float(new['FORCE [N]'].values))
    x1.append(float(new1['FORCE [N]'].values))
    x2.append(float(new2['FORCE [N]'].values))
    d.append(float(new1['FORCE [N]'].values) - float(new2['FORCE [N]'].values))
    a.append(((float(new1['FORCE [N]'].values) - float(new2['FORCE [N]'].values))/(float(new1['FORCE [N]'].values)))*100)

# %%
d_mean = np.mean(a)
d_mean
# Out:
# 0.5614449673478965

# %%
x1
# Out:
# [20.460399627685543,
#  21.25919914245605,
#  21.90359878540039,
#  24.337598800659176,
#  23.678400039672848,
#  21.799999237060543,
#  22.10719871520996,
#  24.258798599243164,
#  21.483200073242188,
#  22.732398986816406,
#  22.40959930419921,
#  22.948398590087887,
#  22.521999359130856,
#  22.47959899902344,
#  21.35599899291992,
#  22.61839866638184]

# %%
x2
# Out:
# [20.25,
#  21.28559875488281,
#  21.67560005187988,
#  24.39439964294433,
#  23.488800048828125,
#  21.669198989868164,
#  21.75160026550293,
#  24.057600021362305,
#  21.497999191284176,
#  22.73959922790528,
#  22.100799560546875,
#  22.94239997863769,
#  22.3135986328125,
#  22.327598571777344,
#  21.41399955749512,
#  22.437599182128903]

# %%
d
# Out:
# [0.21039962768554332,
#  -0.026399612426757812,
#  0.22799873352051137,
#  -0.0568008422851527,
#  0.189599990844723,
#  0.13080024719237926,
#  0.35559844970703125,
#  0.20119857788085938,
#  -0.014799118041988635,
#  -0.007200241088874293,
#  0.30879974365233664,
#  0.0059986114501953125,
#  0.20840072631835582,
#  0.1520004272460973,
#  -0.05800056457520242,
#  0.1807994842529368]

# %%
np.mean(a)
# Out:
# 0.5614449673478965

# %%
x1 = []
x2 = []
d1 = []
a1 = []

objecT = ["Object_1","Object_2","Object_3","Object_4"]
colorCH = ["blue","orange","grey","green"]
ObjectLabel = [ '$\mathbf{Object}$ $\mathbf{1}$', '$\mathbf{Object}$ $\mathbf{2}$','$\mathbf{Object}$ $\mathbf{3}$','$\mathbf{Object}$ $\mathbf{4}$']

seiz = [0,1,2,3]
speed = 300
acc = 300
fig, ax1 = plt.subplots(figsize=(5, 6))
x_axis = np.arange(len(ObjectLabel))
plt.grid(color='0.2', linestyle='-', linewidth=0.3, axis='y')
# ax2 = ax1.twinx()  # share the x-axis, new y-axis


for k in range(len(objecT)):
    x1 = []
    x2 = []
    d1 = []
    a1 = []
    for i in range(1,17):
        object1_x1 = df.loc[(df['OBJECT'] == objecT[k]) 
                   & (df['SPEED'] == speed) 
                   & (df['ACC'] == acc)
                  & (df['SAMPLE'] == i)
                    & (df['TIME [s]'] == 2)]
        object1_x2 = df.loc[(df['OBJECT'] == objecT[k]) 
                   & (df['SPEED'] == speed) 
                   & (df['ACC'] == acc)
                  & (df['SAMPLE'] == i)
                    & (df['TIME [s]'] == 3)]
        # print(float(new['FORCE [N]'].values))
        x1.append(float(object1_x1['FORCE [N]'].values+0.8))    
    
    object1_MinMax = df.loc[(df['OBJECT'] == objecT[k]) 
           & (df['SPEED'] == speed) 
           & (df['ACC'] == acc)
            & (df['TIME [s]'] == 2)]
    plt.bar(+0.0+seiz[k], np.mean(x1), width=0.7, color=colorCH[k], yerr=[[abs(min(object1_MinMax['FORCE [N]'].values+0.8)-np.mean(x1))], [max(object1_MinMax['FORCE [N]'].values+0.8)-np.mean(x1)]], capsize=8)
    #ax2.scatter(0+seiz[k], np.mean(a1), color='red', marker='^', label='Maks. siła - \n$\mathbf{Obiekt}$ $\mathbf{2}$')

plt.ylabel('Average value of jaw squeeze force $\mathbf{F}$[N]',**labelsTNR, size=18)
plt.yticks(np.arange(17.5, 32.5005, 2.5),**labelsTNR, size=16)
plt.ylim(17.5, 32.5)
plt.xticks(x_axis,ObjectLabel,rotation='horizontal', fontsize=16)
plt.tight_layout()

#plt.savefig('{}_{}.png'.format(speed,acc), format='png',dpi=300, bbox_inches='tight')
plt.show()

# %%
x1 = []
x2 = []
d1 = []
a1 = []
zmienna = [] 

objecT = ["Object_1","Object_2","Object_3","Object_4"]
colorCH = ["blue","orange","grey","green"]
ObjectLabel = [ '$\mathbf{Object}$ $\mathbf{1}$', '$\mathbf{Object}$ $\mathbf{2}$','$\mathbf{Object}$ $\mathbf{3}$','$\mathbf{Object}$ $\mathbf{4}$']

seiz = [0,1,2,3]
speed = 300
acc = 300
fig, ax1 = plt.subplots(figsize=(5, 6))
x_axis = np.arange(len(ObjectLabel))
plt.grid(color='0.2', linestyle='-', linewidth=0.3, axis='y')
# ax2 = ax1.twinx()  # share the x-axis, new y-axis


for k in range(len(objecT)):
    x1 = []
    x2 = []
    d1 = []
    a1 = []
    for i in range(1,17):
        object1_x1 = df.loc[(df['OBJECT'] == objecT[k]) 
                   & (df['SPEED'] == speed) 
                   & (df['ACC'] == acc)
                  & (df['SAMPLE'] == i)
                    & (df['TIME [s]'] == 2)]
        object1_x2 = df.loc[(df['OBJECT'] == objecT[k]) 
                   & (df['SPEED'] == speed) 
                   & (df['ACC'] == acc)
                  & (df['SAMPLE'] == i)
                    & (df['TIME [s]'] == 3)]
        # print(float(new['FORCE [N]'].values))
        x1.append(float(object1_x1['FORCE [N]'].values+0.8))
        x2.append(float(object1_x2['FORCE [N]'].values+0.8))
        d1.append(float(object1_x1['FORCE [N]'].values+0.8) - float(object1_x2['FORCE [N]'].values+0.8))
        a1.append(((float(object1_x1['FORCE [N]'].values+0.8) - float(object1_x2['FORCE [N]'].values+0.8))/(float(object1_x1['FORCE [N]'].values+0.8)))*100)
    plt.bar(+0.0+seiz[k], np.mean(a1), width=0.7, color=colorCH[k], yerr=[[abs(min(a1)-np.mean(a1))], [max(a1)-np.mean(a1)]], capsize=8)
    print(np.mean(a1))
plt.ylabel('Average change in jaw squeeze \n force during horizontal movement [%]',**labelsTNR, size=18)
plt.yticks(np.arange(-1.0, 7.0005, 1),**labelsTNR, size=16)
plt.ylim(-1.0, 7.0)
plt.xticks(x_axis,ObjectLabel,rotation='horizontal', fontsize=16)
plt.tight_layout()
#plt.savefig('procZmiana_{}_{}.png'.format(speed,acc), format='png',dpi=300, bbox_inches='tight')
plt.show()
# Out:
# 0.621734293738625
# 1.4110045838087164
# 0.40446602225110906
# 0.0035269917582642016

# %% [markdown]
# Średnie wartości siły dla poszczegolnych konfiguracji speed i acc. na końcu suma i średnia wartośc z średnich.
# Obiekt 1	0.403197909	0.741498817	0.585509081	0.212194706	0.357893543	0.610901226	0.464562036	0.531930662	0.621734294		4.529422273	0.503269141
# Obiekt 2	0.542019439	1.111762217	1.161488859	1.048591005	1.02483754	1.152172424	1.182104767	1.291085905	1.411004584		9.925066739	1.102785193
# Obiekt 3	2.705836088	1.003767305	0.607390598	0.628566212	0.650560567	0.345194041	0.440909545	0.73397398	0.404466022		7.520664358	0.835629373
# Obiekt 4	0.260443786	0.321351669	0.230654812	0.326354723	0.28130757	0.17822108	0.412545314	0.349856165	0.003526992		2.36426211	0.26269579

# %%
x1 = []
x2 = []
d1 = []
a1 = []

objecT = ["Object_1","Object_2","Object_3","Object_4"]
colorCH = ["blue","orange","grey","green"]
ObjectLabel = [ '$\mathbf{Object}$ $\mathbf{1}$', '$\mathbf{Object}$ $\mathbf{2}$','$\mathbf{Object}$ $\mathbf{3}$','$\mathbf{Object}$ $\mathbf{4}$']

seiz = [0,1,2,3]
speed = 300
acc = 300

for k in range(len(objecT)):
    for i in range(1,17):
        object1_x1 = df.loc[(df['OBJECT'] == objecT[k]) 
                   & (df['SPEED'] == speed) 
                   & (df['ACC'] == acc)
                  & (df['SAMPLE'] == i)
                    & (df['TIME [s]'] == 2)]
        object1_x2 = df.loc[(df['OBJECT'] == objecT[k]) 
                   & (df['SPEED'] == speed) 
                   & (df['ACC'] == acc)
                  & (df['SAMPLE'] == i)
                    & (df['TIME [s]'] == 3)]
        # print(float(new['FORCE [N]'].values))
        x1.append(float(object1_x1['FORCE [N]'].values))
        x2.append(float(object1_x2['FORCE [N]'].values))
        d1.append(float(object1_x1['FORCE [N]'].values) - float(object1_x2['FORCE [N]'].values))
        a1.append(((float(object1_x1['FORCE [N]'].values) - float(object1_x2['FORCE [N]'].values))/(float(object1_x1['FORCE [N]'].values)))*100)
    
    print(np.mean(x1))
# Out:
# 25.452999353408813
# 24.871661841869354
# 24.869732817014057
# 25.217461943626404

# %% [markdown]
# Średnie wartości siły dla poszczegolnych konfiguracji speed i acc. na końcu suma i średnia wartośc z średnich.
#
# obiekt 1	23.34929955	25.84659934	25.42707431	24.64302444	26.61799932	25.52994931	24.27374911	25.47029924	25.45299935		226.610994	25.17899933
# obiekt 2	22.87323684	24.88403678	25.20903689	24.52209938	25.69922435	24.99752432	24.60241169	24.89326185	24.87166184		222.5524939	24.72805488
# obiekt 3	22.8154161	24.70436605	25.25324941	25.01777426	25.5943493	25.30188262	25.16184092	25.14833268	24.86973282		223.8669442	24.87410491
# obiekt 4	23.24409318	25.33927441	25.84850565	25.48092425	25.86282429	25.72516182	25.52927431	25.44786188	25.21746194		227.6953817	25.29948686

# %%
x1 = []
x2 = []
d1 = []
a1 = []

objecT = ["Object_1","Object_2","Object_3","Object_4"]
colorCH = ["blue","orange","grey","green"]
ObjectLabel = [ '$\mathbf{Object}$ $\mathbf{1}$', '$\mathbf{Object}$ $\mathbf{2}$','$\mathbf{Object}$ $\mathbf{3}$','$\mathbf{Object}$ $\mathbf{4}$']

seiz = [0,1,2,3]
speed = 300
acc = 300

for k in range(len(objecT)):
    for i in range(1,17):
        object1_x1 = df.loc[(df['OBJECT'] == objecT[k]) 
                   & (df['SPEED'] == speed) 
                   & (df['ACC'] == acc)
                  & (df['SAMPLE'] == i)
                    & (df['TIME [s]'] == 2)]
        object1_x2 = df.loc[(df['OBJECT'] == objecT[k]) 
                   & (df['SPEED'] == speed) 
                   & (df['ACC'] == acc)
                  & (df['SAMPLE'] == i)
                    & (df['TIME [s]'] == 3)]
        # print(float(new['FORCE [N]'].values))
        x1.append(float(object1_x1['FORCE [N]'].values))
        x2.append(float(object1_x2['FORCE [N]'].values))
        d1.append(float(object1_x1['FORCE [N]'].values) - float(object1_x2['FORCE [N]'].values))
        a1.append(((float(object1_x1['FORCE [N]'].values) - float(object1_x2['FORCE [N]'].values))/(float(object1_x1['FORCE [N]'].values)))*100)
    
    print(a1)
# Out:
# [0.30840723821905136, 1.0317770624900002, -0.7035262349241834, 0.6063320853567206, 0.19293579556289303, 0.24527949093661183, 0.7601821210721599, 0.716144806490112, 0.5224548876883056, 0.9996835919218264, 1.5607426486820009, 0.4703332173856676, 1.7156198875394097, 0.453932128513009, 0.9891166920342284, 0.39020931935421754]
# [0.30840723821905136, 1.0317770624900002, -0.7035262349241834, 0.6063320853567206, 0.19293579556289303, 0.24527949093661183, 0.7601821210721599, 0.716144806490112, 0.5224548876883056, 0.9996835919218264, 1.5607426486820009, 0.4703332173856676, 1.7156198875394097, 0.453932128513009, 0.9891166920342284, 0.39020931935421754, 2.3384640401615164, 0.9177486113544513, 1.695271775034345, 1.6636861707891366, 2.513263067797885, 1.3355705663276876, 1.7542883688327682, 1.2647935554457514, 0.8099653409192517, 1.4454027303728358, 1.0631650347726598, 1.981349394939639, 1.371200028145634, 1.1123965001854248, 2.064650952558931, -0.006231998874954179]
# ...
